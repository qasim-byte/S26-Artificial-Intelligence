# %%
data = "My Name is Qasim"
list1 = []
for i in (data.split()):
    list1.append(i.lower())
print("".join(sorted(list1)))
# Out:
# ismynameqasim

# %%
data = "My Name is Qasim"
sorted_data = "".join(sorted(data))
print("Sorted Data is :",sorted_data)
# Out:
# Sorted Data is :    MNQaaeiimmssy

# %%
data = "My Name is Qasim"
data = list(data.split())
data.sort()
print((" ".join(data)))
# Out:
# My Name Qasim is

# %%
#result should be "Ashfaq is My Name Qasim"
data = "My Name is Qasim Ashfaq"
l = []
for word in data.split():
    l.append((word.capitalize()))
print(sorted(l))
l1 = []

for i in range(0,len(l)):
   
    if i == 1:
        print(sorted(l)[i].lower(),end = ' ')
    else:
        print(sorted(l)[i],end = " ")
# Out:
# ['Ashfaq', 'Is', 'My', 'Name', 'Qasim']
# Ashfaq is My Name Qasim
