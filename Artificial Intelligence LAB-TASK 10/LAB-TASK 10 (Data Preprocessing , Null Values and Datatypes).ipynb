# %% [markdown]
# <div style='background: linear-gradient(135deg, #1a1a2e 0%, #16213e 50%, #0f3460 100%); padding: 40px 36px; border-radius: 16px; margin-bottom: 10px;'>
#   <h1 style='color: #e94560; font-family: Georgia, serif; font-size: 2.4em; margin: 0 0 8px 0; letter-spacing: 1px;'> Student Performance Analysis</h1>
#   <p style='color: #a8b2d8; font-family: Arial, sans-serif; font-size: 1.05em; margin: 0;'>Exploratory Data Analysis </p>
#   <hr style='border: none; border-top: 1px solid #e9456044; margin: 18px 0 14px 0;'/>
#   <div style='display: flex; gap: 32px; flex-wrap: wrap;'>
#
#   </div>
# </div>

# %% [markdown]
# <div style='background: #0d1117; border-left: 5px solid #e94560; padding: 18px 24px; border-radius: 8px; margin: 6px 0;'>
#   <h2 style='color: #e94560; font-family: Arial, sans-serif; margin: 0 0 6px 0; font-size: 1.3em;'>Import Libraries</h2>
#   <p style='color: #8b949e; font-family: Arial, sans-serif; margin: 0; font-size: 0.93em;'>Loading all necessary libraries for data manipulation and visualization.</p>
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
sns.set_theme(style='darkgrid', palette='muted')
plt.rcParams['figure.dpi'] = 120
plt.rcParams['font.family'] = 'DejaVu Sans'

print('Libraries loaded successfully ')
# Out:
# Libraries loaded successfully

# %% [markdown]
# <div style='background: #0d1117; border-left: 5px solid #58a6ff; padding: 18px 24px; border-radius: 8px; margin: 6px 0;'>
#   <h2 style='color: #58a6ff; font-family: Arial, sans-serif; margin: 0 0 6px 0; font-size: 1.3em;'>Load Dataset</h2>
#   <p style='color: #8b949e; font-family: Arial, sans-serif; margin: 0; font-size: 0.93em;'>Reading the CSV file and taking a first look at the raw data.</p>
# </div>

# %%
df = pd.read_csv(r"C:\Muhammad Qasim Ashfaq\University A\Artificial Intelligence\LAB AI\Artificial Intelligence LAB-TASK 10\Student_performance_data __.csv")

print(f'Shape: {df.shape[0]} rows × {df.shape[1]} columns')
print(f'\nColumn names:')
for col in df.columns:
    print(f'  → {col}')
# Out:
# Shape: 2392 rows × 15 columns
#
# Column names:
#   → StudentID
#   → Age
#   → Gender
#   → Ethnicity
#   → ParentalEducation
#   → StudyTimeWeekly
#   → Absences
#   → Tutoring
#   → ParentalSupport
#   → Extracurricular
#   → Sports
#   → Music
#   → Volunteering
#   → GPA
#   → GradeClass

# %%
df.head(10)
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
# 5       1006   18       0          0                  1         8.191219
# 6       1007   15       0          1                  1        15.601680
# 7       1008   15       1          1                  4        15.424496
# 8       1009   17       0          0                  0         4.562008
# 9       1010   16       1          0                  1        18.444466
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# ...

# %%
df.tail(5)
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
#       Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 2387         2         0                4                1       0      0
# 2388         4         1                4                0       1      0
# 2389        20         0                2                0       0      0
# 2390        17         0                2                0       1      1
# 2391        13         0                2                0       0      0
#
#       Volunteering       GPA  GradeClass
# ...

# %% [markdown]
# <div style='background: #0d1117; border-left: 5px solid #3fb950; padding: 18px 24px; border-radius: 8px; margin: 6px 0;'>
#   <h2 style='color: #3fb950; font-family: Arial, sans-serif; margin: 0 0 6px 0; font-size: 1.3em;'>Data Types & Structure</h2>
#   <p style='color: #8b949e; font-family: Arial, sans-serif; margin: 0; font-size: 0.93em;'>Understanding what types of data each column holds and the overall structure.</p>
# </div>

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StudentID          2392 non-null   int64
#  1   Age                2392 non-null   int64
#  2   Gender             2392 non-null   int64
#  3   Ethnicity          2392 non-null   int64
#  4   ParentalEducation  2392 non-null   int64
#  5   StudyTimeWeekly    2392 non-null   float64
#  6   Absences           2392 non-null   int64
#  7   Tutoring           2392 non-null   int64
#  8   ParentalSupport    2392 non-null   int64
#  9   Extracurricular    2392 non-null   int64
#  10  Sports             2392 non-null   int64
#  11  Music              2392 non-null   int64
#  12  Volunteering       2392 non-null   int64
#  13  GPA                2392 non-null   float64
#  14  GradeClass         2392 non-null   float64
# dtypes: float64(3), int64(12)
# memory usage: 280.4 KB

# %%
print('Data Types:')
print(df.dtypes)
print(f'\nTotal memory usage: {df.memory_usage(deep=True).sum() / 1024:.2f} KB')
# Out:
# Data Types:
# StudentID              int64
# Age                    int64
# Gender                 int64
# Ethnicity              int64
# ParentalEducation      int64
# StudyTimeWeekly      float64
# Absences               int64
# Tutoring               int64
# ParentalSupport        int64
# Extracurricular        int64
# Sports                 int64
# Music                  int64
# Volunteering           int64
# GPA                  float64
# GradeClass           float64
# dtype: object
#
# Total memory usage: 280.44 KB

# %% [markdown]
# <div style='background: #0d1117; border-left: 5px solid #f78166; padding: 18px 24px; border-radius: 8px; margin: 6px 0;'>
#   <h2 style='color: #f78166; font-family: Arial, sans-serif; margin: 0 0 6px 0; font-size: 1.3em;'>Missing Values & Duplicates [LAB TASK 10]</h2>
#   <p style='color: #8b949e; font-family: Arial, sans-serif; margin: 0; font-size: 0.93em;'>Checking for nulls, duplicates, and any inconsistencies.</p>
# </div>

# %%
missing = df.isnull().sum()
missing_pct = (missing / len(df)) * 100
missing_df = pd.DataFrame({'Missing Count': missing, 'Missing %': missing_pct.round(2)})
print('Missing Values Summary:')
print(missing_df[missing_df['Missing Count'] > 0] if missing.sum() > 0 else ' No missing values found!')
# Out:
# Missing Values Summary:
#  No missing values found!

# %%
duplicates = df.duplicated().sum()
print(f'Duplicate rows: {duplicates}')
print(f'Unique StudentIDs: {df["StudentID"].nunique()}')
print(f'Total rows: {len(df)}')
# Out:
# Duplicate rows: 0
# Unique StudentIDs: 2392
# Total rows: 2392

# %% [markdown]
# <div style='background: #0d1117; border-left: 5px solid #d2a8ff; padding: 18px 24px; border-radius: 8px; margin: 6px 0;'>
#   <h2 style='color: #d2a8ff; font-family: Arial, sans-serif; margin: 0 0 6px 0; font-size: 1.3em;'>Descriptive Statistics</h2>
#   <p style='color: #8b949e; font-family: Arial, sans-serif; margin: 0; font-size: 0.93em;'>Summary statistics for mean, std, min, max, quartiles.</p>
# </div>

# %%
df.describe().round(3)
# Out:
#        StudentID       Age    Gender  Ethnicity  ParentalEducation  \
# count   2392.000  2392.000  2392.000   2392.000           2392.000
# mean    2196.500    16.469     0.511      0.878              1.746
# std      690.655     1.124     0.500      1.028              1.000
# min     1001.000    15.000     0.000      0.000              0.000
# 25%     1598.750    15.000     0.000      0.000              1.000
# 50%     2196.500    16.000     1.000      0.000              2.000
# 75%     2794.250    17.000     1.000      2.000              2.000
# max     3392.000    18.000     1.000      3.000              4.000
#
#        StudyTimeWeekly  Absences  Tutoring  ParentalSupport  Extracurricular  \
# count         2392.000  2392.000  2392.000         2392.000         2392.000
# mean             9.772    14.541     0.301            2.122            0.383
# std              5.653     8.467     0.459            1.123            0.486
# ...

# %%
print('Key Observations:')
print(f'  Average GPA       : {df["GPA"].mean():.3f}')
print(f'  Median GPA        : {df["GPA"].median():.3f}')
print(f'  GPA Std Dev       : {df["GPA"].std():.3f}')
print(f'  Avg Study Hrs/wk  : {df["StudyTimeWeekly"].mean():.2f}')
print(f'  Avg Absences      : {df["Absences"].mean():.2f}')
print(f'  Age Range         : {df["Age"].min()} - {df["Age"].max()}')
# Out:
# Key Observations:
#   Average GPA       : 1.906
#   Median GPA        : 1.893
#   GPA Std Dev       : 0.915
#   Avg Study Hrs/wk  : 9.77
#   Avg Absences      : 14.54
#   Age Range         : 15 - 18

# %% [markdown]
# <div style='background: #0d1117; border-left: 5px solid #ffa657; padding: 18px 24px; border-radius: 8px; margin: 6px 0;'>
#   <h2 style='color: #ffa657; font-family: Arial, sans-serif; margin: 0 0 6px 0; font-size: 1.3em;'>🔢 Step 6 — Categorical Feature Analysis</h2>
#   <p style='color: #8b949e; font-family: Arial, sans-serif; margin: 0; font-size: 0.93em;'>Value counts and distributions for encoded categorical features.</p>
# </div>

# %%
cat_cols = ['Gender', 'Ethnicity', 'ParentalEducation', 'Tutoring',
            'ParentalSupport', 'Extracurricular', 'Sports', 'Music',
            'Volunteering', 'GradeClass']

for col in cat_cols:
    print(f'\n{col}:')
    vc = df[col].value_counts().sort_index()
    for val, count in vc.items():
        print(f'  {val} → {count} students ({count/len(df)*100:.1f}%)')
# Out:
# Gender:
#   0 → 1170 students (48.9%)
#   1 → 1222 students (51.1%)
#
# Ethnicity:
#   0 → 1207 students (50.5%)
#   1 → 493 students (20.6%)
#   2 → 470 students (19.6%)
#   3 → 222 students (9.3%)
#
# ParentalEducation:
#   0 → 243 students (10.2%)
#   1 → 728 students (30.4%)
#   2 → 934 students (39.0%)
#   3 → 367 students (15.3%)
#   4 → 120 students (5.0%)
#
# Tutoring:
#   0 → 1671 students (69.9%)
#   1 → 721 students (30.1%)
#
# ParentalSupport:
#   0 → 212 students (8.9%)
#   1 → 489 students (20.4%)
#   2 → 740 students (30.9%)
#   3 → 697 students (29.1%)
#   4 → 254 students (10.6%)
#
# Extracurricular:
#   0 → 1475 students (61.7%)
#   1 → 917 students (38.3%)
#
# Sports:
#   0 → 1666 students (69.6%)
#   1 → 726 students (30.4%)
#
# Music:
#   0 → 1921 students (80.3%)
#   1 → 471 students (19.7%)
#
# Volunteering:
#   0 → 2016 students (84.3%)
#   1 → 376 students (15.7%)
#
# GradeClass:
#   0.0 → 107 students (4.5%)
#   1.0 → 269 students (11.2%)
# ...

# %% [markdown]
# <div style='background: #0d1117; border-left: 5px solid #79c0ff; padding: 18px 24px; border-radius: 8px; margin: 6px 0;'>
#   <h2 style='color: #79c0ff; font-family: Arial, sans-serif; margin: 0 0 6px 0; font-size: 1.3em;'>Changing the DataType of Column</h2>
#
# </div>

# %%
print("Original dtype:", df['StudyTimeWeekly'].dtype)
# Out:
# Original dtype: float64

# %%
df['StudyTimeWeekly']=df['StudyTimeWeekly'].astype(int)
print("After conversion:", df['StudyTimeWeekly'].dtype)
# Out:
# After conversion: int64
